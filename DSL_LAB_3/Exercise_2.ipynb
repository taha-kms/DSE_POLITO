# %%
import numpy as np
import pandas as pd
from collections import defaultdict
import json, requests, timeit
from mlxtend.frequent_patterns import apriori, fpgrowth
import pandas as pd

# %% [markdown]
# ***Implement Apriori Algorithm***<br>
# The Apriori algorithm is used to extract frequent itemsets from a dataset using the concept of support. Below is the approach:
#
# Key Steps of Apriori:
#
# 1. Generate candidate itemsets of length 1 (C1) and count their frequency.
# 2. Prune itemsets that don’t meet the minimum support threshold.
# 3. Generate candidate itemsets of length k+1 by combining frequent itemsets of length k (Ck+1).
# 4. Repeat until no more itemsets can be generated.

# %%
def implemented_apriori(dataset, min_support):
    # Step 1: Count frequency of each item
    item_counts = defaultdict(int)
    for transaction in dataset:
        for item in transaction:
            item_counts[item] += 1

    # Step 2: Filter items by min_support
    num_transactions = len(dataset)
    min_count = num_transactions * min_support
    frequent_items = {item for item, count in item_counts.items() if count >= min_count}

    # Step 3: Generate frequent itemsets
    frequent_itemsets = []
    k = 1
    current_itemsets = [{item} for item in frequent_items]

    while current_itemsets:
        # Count frequency of current itemsets
        itemset_counts = defaultdict(int)
        for transaction in dataset:
            for itemset in current_itemsets:
                if itemset.issubset(transaction):
                    itemset_counts[frozenset(itemset)] += 1

        # Filter by min_support
        current_itemsets = [
            itemset for itemset, count in itemset_counts.items()
            if count >= min_count
        ]
        frequent_itemsets.extend(current_itemsets)

        # Generate combinations for next level
        k += 1
        current_itemsets = [set(a).union(set(b)) for a in current_itemsets for b in current_itemsets if len(a.union(b)) == k]

    return frequent_itemsets

# %% [markdown]
# ***2. Load and Transform COCO Dataset***
#
# The COCO dataset contains image annotations. Each image is considered a transaction, and the annotations are the items.

# %%
url = "https://raw.githubusercontent.com/dbdmg/data-science-lab/master/datasets/modified_coco.json"

file_path = "modified_coco.json"

# Download the file
response = requests.get(url)


with open(file_path, "wb") as file:
    file.write(response.content)
    print(f"File downloaded successfully: {file_path}")
# Out:
# File downloaded successfully: modified_coco.json

# %%
with open(file_path) as file:
    data = json.load(file)

dataset = [image['annotations'] for image in data]
dataset[:5]
# Out:
# [['car', 'car', 'train', 'stop sign'],
#  ['person',
#   'person',
#   'person',
#   'person',
#   'person',
#   'bench',
#   'chair',
#   'chair',
#   'chair',
#   'chair',
#   'chair',
#   'chair',
#   'potted plant',
#   'potted plant',
#   'potted plant',
#   'dining table',
#   'dining table',
#   'dining table'],
#  ['stop sign'],
#  ['person', 'fire hydrant'],
#  ['bicycle', 'bicycle', 'fire hydrant']]

# %% [markdown]
# ***3. Run Apriori on COCO Dataset***

# %%
# Run Apriori with a minimum support of 0.02
frequent_itemsets = implemented_apriori(dataset, min_support=0.02)

# Display the frequent itemsets
print("Frequent Itemsets with min_support=0.02:")
for itemset in frequent_itemsets:
    print(itemset)
# Out:
# Frequent Itemsets with min_support=0.02:
# frozenset({'train'})
# frozenset({'stop sign'})
# frozenset({'car'})
# frozenset({'bench'})
# frozenset({'person'})
# frozenset({'chair'})
# frozenset({'potted plant'})
# frozenset({'dining table'})
# frozenset({'fire hydrant'})
# frozenset({'bicycle'})
# frozenset({'bus'})
# frozenset({'backpack'})
# frozenset({'parking meter'})
# frozenset({'truck'})
# frozenset({'umbrella'})
# frozenset({'traffic light'})
# frozenset({'clock'})
# frozenset({'motorcycle'})
# frozenset({'dog'})
# frozenset({'handbag'})
# frozenset({'baseball bat'})
# frozenset({'sports ball'})
# frozenset({'tennis racket'})
# frozenset({'bird'})
# frozenset({'baseball glove'})
# frozenset({'cell phone'})
# frozenset({'bottle'})
# frozenset({'suitcase'})
# frozenset({'skateboard'})
# frozenset({'cup'})
# frozenset({'stop sign', 'car'})
# frozenset({'person', 'bench'})
# frozenset({'bench', 'chair'})
# frozenset({'bench', 'potted plant'})
# frozenset({'dining table', 'bench'})
# frozenset({'person', 'chair'})
# frozenset({'person', 'potted plant'})
# frozenset({'dining table', 'person'})
# frozenset({'dining table', 'chair'})
# frozenset({'person', 'fire hydrant'})
# frozenset({'person', 'car'})
# frozenset({'fire hydrant', 'car'})
# frozenset({'bus', 'car'})
# frozenset({'car', 'backpack'})
# frozenset({'person', 'bus'})
# frozenset({'person', 'backpack'})
# frozenset({'bus', 'backpack'})
# frozenset({'bicycle', 'bench'})
# frozenset({'truck', 'bench'})
# frozenset({'bicycle', 'person'})
# frozenset({'truck', 'person'})
# frozenset({'bicycle', 'truck'})
# frozenset({'bench', 'umbrella'})
# frozenset({'person', 'umbrella'})
# frozenset({'stop sign', 'person'})
# frozenset({'truck', 'car'})
# frozenset({'traffic light', 'car'})
# frozenset({'truck', 'bus'})
# frozenset({'traffic light', 'bus'})
# frozenset({'truck', 'traffic light'})
# frozenset({'person', 'traffic light'})
# frozenset({'traffic light', 'backpack'})
# frozenset({'bench', 'train'})
# frozenset({'person', 'train'})
# frozenset({'bench', 'clock'})
# frozenset({'person', 'clock'})
# frozenset({'chair', 'car'})
# frozenset({'bicycle', 'car'})
# frozenset({'motorcycle', 'car'})
# frozenset({'motorcycle', 'person'})
# frozenset({'bicycle', 'bus'})
# frozenset({'bicycle', 'backpack'})
# frozenset({'bicycle', 'traffic light'})
# frozenset({'motorcycle', 'traffic light'})
# frozenset({'bench', 'car'})
# frozenset({'bench', 'bus'})
# frozenset({'truck', 'motorcycle'})
# frozenset({'traffic light', 'train'})
# frozenset({'handbag', 'car'})
# frozenset({'person', 'dog'})
# frozenset({'person', 'handbag'})
# frozenset({'handbag', 'backpack'})
# frozenset({'traffic light', 'handbag'})
# frozenset({'bench', 'baseball bat'})
# frozenset({'person', 'baseball bat'})
# frozenset({'bench', 'sports ball'})
# frozenset({'bench', 'tennis racket'})
# frozenset({'person', 'sports ball'})
# frozenset({'person', 'tennis racket'})
# frozenset({'sports ball', 'tennis racket'})
# frozenset({'clock', 'car'})
# frozenset({'truck', 'fire hydrant'})
# frozenset({'fire hydrant', 'traffic light'})
# frozenset({'traffic light', 'clock'})
# frozenset({'baseball glove', 'bench'})
# frozenset({'person', 'baseball glove'})
# frozenset({'baseball glove', 'baseball bat'})
# frozenset({'parking meter', 'car'})
# frozenset({'bench', 'handbag'})
# frozenset({'cell phone', 'bench'})
# frozenset({'person', 'cell phone'})
# frozenset({'cell phone', 'handbag'})
# frozenset({'fire hydrant', 'handbag'})
# frozenset({'parking meter', 'person'})
# frozenset({'car', 'umbrella'})
# frozenset({'baseball bat', 'sports ball'})
# frozenset({'bench', 'backpack'})
# frozenset({'bench', 'bottle'})
# frozenset({'person', 'bottle'})
# frozenset({'truck', 'stop sign'})
# frozenset({'person', 'suitcase'})
# frozenset({'truck', 'backpack'})
# frozenset({'skateboard', 'bench'})
# frozenset({'person', 'skateboard'})
# frozenset({'cell phone', 'car'})
# frozenset({'traffic light', 'bench'})
# frozenset({'bench', 'suitcase'})
# frozenset({'handbag', 'bus'})
# frozenset({'traffic light', 'umbrella'})
# frozenset({'bench', 'dog'})
# frozenset({'handbag', 'umbrella'})
# frozenset({'stop sign', 'traffic light'})
# frozenset({'bird', 'bench'})
# frozenset({'bird', 'person'})
# frozenset({'bicycle', 'handbag'})
# frozenset({'truck', 'handbag'})
# frozenset({'skateboard', 'car'})
# frozenset({'bench', 'cup'})
# frozenset({'person', 'cup'})
# frozenset({'dining table', 'cup'})
# frozenset({'baseball glove', 'sports ball'})
# frozenset({'potted plant', 'car'})
# frozenset({'person', 'bench', 'chair'})
# frozenset({'person', 'bench', 'potted plant'})
# frozenset({'dining table', 'person', 'bench'})
# frozenset({'dining table', 'bench', 'chair'})
# frozenset({'dining table', 'person', 'chair'})
# frozenset({'person', 'fire hydrant', 'car'})
# frozenset({'person', 'bus', 'car'})
# frozenset({'person', 'car', 'backpack'})
# frozenset({'bus', 'car', 'backpack'})
# frozenset({'person', 'bus', 'backpack'})
# frozenset({'bicycle', 'person', 'bench'})
# frozenset({'truck', 'person', 'bench'})
# frozenset({'bicycle', 'truck', 'person'})
# frozenset({'person', 'bench', 'umbrella'})
# frozenset({'truck', 'bus', 'car'})
# frozenset({'traffic light', 'bus', 'car'})
# frozenset({'truck', 'traffic light', 'car'})
# frozenset({'truck', 'traffic light', 'bus'})
# frozenset({'person', 'traffic light', 'backpack'})
# frozenset({'person', 'bench', 'train'})
# frozenset({'person', 'bench', 'clock'})
# frozenset({'person', 'chair', 'car'})
# frozenset({'bicycle', 'person', 'car'})
# frozenset({'person', 'traffic light', 'car'})
# frozenset({'motorcycle', 'person', 'car'})
# frozenset({'bicycle', 'bus', 'car'})
# frozenset({'traffic light', 'car', 'backpack'})
# frozenset({'bicycle', 'car', 'backpack'})
# frozenset({'bicycle', 'person', 'bus'})
# frozenset({'person', 'traffic light', 'bus'})
# frozenset({'bicycle', 'person', 'backpack'})
# frozenset({'traffic light', 'bus', 'backpack'})
# frozenset({'bicycle', 'bus', 'backpack'})
# frozenset({'bicycle', 'person', 'traffic light'})
# frozenset({'bicycle', 'traffic light', 'car'})
# frozenset({'motorcycle', 'traffic light', 'car'})
# frozenset({'bicycle', 'traffic light', 'bus'})
# frozenset({'motorcycle', 'person', 'traffic light'})
# frozenset({'bicycle', 'traffic light', 'backpack'})
# frozenset({'person', 'bench', 'car'})
# frozenset({'person', 'bench', 'bus'})
# frozenset({'truck', 'person', 'car'})
# frozenset({'bench', 'bus', 'car'})
# frozenset({'truck', 'person', 'bus'})
# frozenset({'bicycle', 'bench', 'car'})
# frozenset({'truck', 'bench', 'car'})
# frozenset({'truck', 'person', 'motorcycle'})
# frozenset({'bicycle', 'truck', 'car'})
# frozenset({'bicycle', 'truck', 'bus'})
# frozenset({'truck', 'motorcycle', 'car'})
# frozenset({'person', 'handbag', 'car'})
# frozenset({'handbag', 'car', 'backpack'})
# frozenset({'person', 'handbag', 'backpack'})
# frozenset({'traffic light', 'handbag', 'car'})
# frozenset({'person', 'traffic light', 'handbag'})
# frozenset({'traffic light', 'handbag', 'backpack'})
# frozenset({'person', 'bench', 'baseball bat'})
# frozenset({'person', 'bench', 'sports ball'})
# frozenset({'person', 'bench', 'tennis racket'})
# frozenset({'bench', 'sports ball', 'tennis racket'})
# frozenset({'person', 'sports ball', 'tennis racket'})
# frozenset({'truck', 'person', 'fire hydrant'})
# frozenset({'person', 'fire hydrant', 'traffic light'})
# frozenset({'person', 'clock', 'car'})
# frozenset({'truck', 'fire hydrant', 'car'})
# frozenset({'fire hydrant', 'traffic light', 'car'})
# frozenset({'truck', 'person', 'traffic light'})
# frozenset({'traffic light', 'clock', 'car'})
# frozenset({'truck', 'traffic light', 'fire hydrant'})
# frozenset({'person', 'clock', 'traffic light'})
# frozenset({'stop sign', 'person', 'car'})
# frozenset({'person', 'bench', 'baseball glove'})
# frozenset({'baseball glove', 'bench', 'baseball bat'})
# frozenset({'person', 'baseball bat', 'baseball glove'})
# frozenset({'person', 'bench', 'handbag'})
# frozenset({'person', 'bench', 'cell phone'})
# frozenset({'person', 'cell phone', 'handbag'})
# frozenset({'cell phone', 'bench', 'handbag'})
# frozenset({'person', 'fire hydrant', 'handbag'})
# frozenset({'bicycle', 'truck', 'traffic light'})
# frozenset({'parking meter', 'person', 'car'})
# frozenset({'bench', 'chair', 'car'})
# frozenset({'person', 'car', 'umbrella'})
# frozenset({'bench', 'car', 'umbrella'})
# frozenset({'bench', 'baseball bat', 'sports ball'})
# frozenset({'person', 'baseball bat', 'sports ball'})
# frozenset({'person', 'bench', 'backpack'})
# frozenset({'person', 'bench', 'bottle'})
# frozenset({'truck', 'stop sign', 'car'})
# frozenset({'truck', 'car', 'backpack'})
# frozenset({'truck', 'person', 'backpack'})
# frozenset({'stop sign', 'truck', 'person'})
# frozenset({'person', 'bench', 'skateboard'})
# frozenset({'bicycle', 'bench', 'backpack'})
# frozenset({'person', 'cell phone', 'car'})
# frozenset({'cell phone', 'bench', 'car'})
# frozenset({'bench', 'handbag', 'car'})
# frozenset({'cell phone', 'handbag', 'car'})
# frozenset({'person', 'bench', 'traffic light'})
# frozenset({'bench', 'car', 'backpack'})
# frozenset({'traffic light', 'bench', 'car'})
# frozenset({'person', 'bench', 'suitcase'})
# frozenset({'handbag', 'bus', 'car'})
# frozenset({'person', 'handbag', 'bus'})
# frozenset({'traffic light', 'handbag', 'bus'})
# frozenset({'person', 'traffic light', 'umbrella'})
# frozenset({'traffic light', 'car', 'umbrella'})
# frozenset({'person', 'bench', 'dog'})
# frozenset({'person', 'handbag', 'umbrella'})
# frozenset({'handbag', 'car', 'umbrella'})
# frozenset({'traffic light', 'handbag', 'umbrella'})
# frozenset({'traffic light', 'bench', 'bus'})
# frozenset({'bird', 'person', 'bench'})
# frozenset({'bicycle', 'person', 'handbag'})
# frozenset({'bicycle', 'handbag', 'car'})
# frozenset({'bicycle', 'traffic light', 'handbag'})
# frozenset({'truck', 'person', 'handbag'})
# frozenset({'truck', 'handbag', 'car'})
# frozenset({'truck', 'traffic light', 'handbag'})
# frozenset({'person', 'skateboard', 'car'})
# frozenset({'bench', 'clock', 'car'})
# frozenset({'truck', 'traffic light', 'motorcycle'})
# frozenset({'stop sign', 'traffic light', 'car'})
# frozenset({'bench', 'handbag', 'umbrella'})
# frozenset({'truck', 'handbag', 'bus'})
# frozenset({'bench', 'handbag', 'bus'})
# frozenset({'person', 'bench', 'cup'})
# frozenset({'dining table', 'bench', 'cup'})
# frozenset({'dining table', 'person', 'cup'})
# frozenset({'bicycle', 'bench', 'handbag'})
# frozenset({'bicycle', 'handbag', 'bus'})
# frozenset({'traffic light', 'bench', 'handbag'})
# frozenset({'baseball glove', 'bench', 'sports ball'})
# frozenset({'person', 'sports ball', 'baseball glove'})
# frozenset({'baseball glove', 'baseball bat', 'sports ball'})
# frozenset({'truck', 'traffic light', 'backpack'})
# frozenset({'bench', 'potted plant', 'car'})
# frozenset({'person', 'potted plant', 'car'})
# frozenset({'bench', 'handbag', 'backpack'})
# frozenset({'fire hydrant', 'handbag', 'car'})
# frozenset({'handbag', 'bus', 'backpack'})
# frozenset({'bicycle', 'handbag', 'backpack'})
# frozenset({'truck', 'handbag', 'backpack'})
# frozenset({'skateboard', 'bench', 'car'})
# frozenset({'truck', 'bus', 'backpack'})
# frozenset({'person', 'traffic light', 'train'})
# frozenset({'stop sign', 'person', 'traffic light'})
# frozenset({'dining table', 'person', 'bench', 'chair'})
# frozenset({'person', 'bus', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'bus', 'car'})
# frozenset({'traffic light', 'person', 'bus', 'car'})
# frozenset({'bicycle', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'person', 'car', 'backpack'})
# frozenset({'bicycle', 'person', 'car', 'backpack'})
# frozenset({'traffic light', 'bus', 'car', 'backpack'})
# frozenset({'bicycle', 'bus', 'car', 'backpack'})
# frozenset({'traffic light', 'person', 'bus', 'backpack'})
# frozenset({'bicycle', 'person', 'bus', 'backpack'})
# frozenset({'bicycle', 'traffic light', 'bus', 'car'})
# frozenset({'bicycle', 'traffic light', 'person', 'backpack'})
# frozenset({'bicycle', 'traffic light', 'person', 'car'})
# frozenset({'motorcycle', 'traffic light', 'person', 'car'})
# frozenset({'bicycle', 'traffic light', 'car', 'backpack'})
# frozenset({'bicycle', 'traffic light', 'person', 'bus'})
# frozenset({'bicycle', 'traffic light', 'bus', 'backpack'})
# frozenset({'truck', 'person', 'bus', 'car'})
# frozenset({'person', 'bench', 'bus', 'car'})
# frozenset({'bicycle', 'person', 'bench', 'car'})
# frozenset({'truck', 'person', 'bench', 'car'})
# frozenset({'bicycle', 'truck', 'person', 'car'})
# frozenset({'bicycle', 'truck', 'person', 'bus'})
# frozenset({'bicycle', 'truck', 'bus', 'car'})
# frozenset({'truck', 'person', 'motorcycle', 'car'})
# frozenset({'person', 'car', 'handbag', 'backpack'})
# frozenset({'traffic light', 'person', 'handbag', 'backpack'})
# frozenset({'traffic light', 'person', 'car', 'handbag'})
# frozenset({'traffic light', 'car', 'handbag', 'backpack'})
# frozenset({'person', 'bench', 'sports ball', 'tennis racket'})
# frozenset({'traffic light', 'fire hydrant', 'car', 'person'})
# frozenset({'truck', 'fire hydrant', 'person', 'car'})
# frozenset({'truck', 'traffic light', 'person', 'car'})
# frozenset({'truck', 'traffic light', 'fire hydrant', 'car'})
# frozenset({'traffic light', 'person', 'clock', 'car'})
# frozenset({'truck', 'traffic light', 'fire hydrant', 'person'})
# frozenset({'truck', 'traffic light', 'person', 'bus'})
# frozenset({'baseball glove', 'bench', 'baseball bat', 'person'})
# frozenset({'person', 'bench', 'cell phone', 'handbag'})
# frozenset({'bicycle', 'truck', 'traffic light', 'person'})
# frozenset({'bicycle', 'truck', 'traffic light', 'car'})
# frozenset({'bicycle', 'truck', 'traffic light', 'bus'})
# frozenset({'person', 'bench', 'chair', 'car'})
# frozenset({'person', 'bench', 'car', 'umbrella'})
# frozenset({'person', 'bench', 'baseball bat', 'sports ball'})
# frozenset({'truck', 'person', 'car', 'backpack'})
# frozenset({'stop sign', 'truck', 'person', 'car'})
# frozenset({'bicycle', 'person', 'bench', 'backpack'})
# frozenset({'person', 'bench', 'cell phone', 'car'})
# frozenset({'person', 'bench', 'car', 'handbag'})
# frozenset({'person', 'cell phone', 'car', 'handbag'})
# frozenset({'person', 'bench', 'car', 'backpack'})
# frozenset({'traffic light', 'bench', 'car', 'person'})
# frozenset({'person', 'car', 'bus', 'handbag'})
# frozenset({'traffic light', 'car', 'bus', 'handbag'})
# frozenset({'traffic light', 'person', 'bus', 'handbag'})
# frozenset({'traffic light', 'person', 'car', 'umbrella'})
# frozenset({'person', 'car', 'handbag', 'umbrella'})
# frozenset({'traffic light', 'car', 'handbag', 'umbrella'})
# frozenset({'traffic light', 'person', 'handbag', 'umbrella'})
# frozenset({'traffic light', 'bench', 'bus', 'car'})
# frozenset({'traffic light', 'bench', 'bus', 'person'})
# frozenset({'bicycle', 'person', 'car', 'handbag'})
# frozenset({'bicycle', 'traffic light', 'person', 'handbag'})
# frozenset({'bicycle', 'traffic light', 'car', 'handbag'})
# frozenset({'truck', 'traffic light', 'car', 'handbag'})
# frozenset({'truck', 'person', 'car', 'handbag'})
# frozenset({'truck', 'traffic light', 'person', 'handbag'})
# frozenset({'person', 'bench', 'clock', 'car'})
# frozenset({'truck', 'traffic light', 'motorcycle', 'car'})
# frozenset({'truck', 'traffic light', 'motorcycle', 'person'})
# frozenset({'person', 'bench', 'handbag', 'umbrella'})
# frozenset({'person', 'bench', 'bus', 'handbag'})
# frozenset({'truck', 'person', 'bus', 'handbag'})
# frozenset({'dining table', 'person', 'bench', 'cup'})
# frozenset({'bicycle', 'person', 'bench', 'handbag'})
# frozenset({'bicycle', 'person', 'bus', 'handbag'})
# frozenset({'bicycle', 'traffic light', 'bus', 'handbag'})
# frozenset({'traffic light', 'bench', 'handbag', 'person'})
# frozenset({'baseball glove', 'bench', 'sports ball', 'person'})
# frozenset({'baseball glove', 'bench', 'baseball bat', 'sports ball'})
# frozenset({'baseball glove', 'person', 'baseball bat', 'sports ball'})
# frozenset({'truck', 'traffic light', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'person', 'backpack'})
# frozenset({'person', 'bench', 'potted plant', 'car'})
# frozenset({'person', 'bench', 'handbag', 'backpack'})
# frozenset({'fire hydrant', 'person', 'car', 'handbag'})
# frozenset({'car', 'bus', 'handbag', 'backpack'})
# frozenset({'person', 'bus', 'handbag', 'backpack'})
# frozenset({'traffic light', 'bus', 'handbag', 'backpack'})
# frozenset({'bicycle', 'car', 'handbag', 'backpack'})
# frozenset({'bicycle', 'person', 'handbag', 'backpack'})
# frozenset({'bicycle', 'traffic light', 'handbag', 'backpack'})
# frozenset({'truck', 'car', 'handbag', 'backpack'})
# frozenset({'truck', 'person', 'handbag', 'backpack'})
# frozenset({'truck', 'traffic light', 'handbag', 'backpack'})
# frozenset({'skateboard', 'bench', 'car', 'person'})
# frozenset({'truck', 'bus', 'car', 'backpack'})
# frozenset({'truck', 'person', 'bus', 'backpack'})
# frozenset({'truck', 'traffic light', 'bus', 'backpack'})
# frozenset({'truck', 'car', 'bus', 'handbag'})
# frozenset({'truck', 'traffic light', 'bus', 'handbag'})
# frozenset({'bicycle', 'car', 'bus', 'handbag'})
# frozenset({'traffic light', 'bench', 'car', 'handbag'})
# frozenset({'car', 'bench', 'handbag', 'umbrella'})
# frozenset({'stop sign', 'traffic light', 'person', 'car'})
# frozenset({'car', 'bench', 'handbag', 'backpack'})
# frozenset({'car', 'bench', 'bus', 'handbag'})
# frozenset({'traffic light', 'person', 'bus', 'car', 'backpack'})
# frozenset({'bicycle', 'person', 'bus', 'car', 'backpack'})
# frozenset({'traffic light', 'bicycle', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'bicycle', 'person', 'car', 'backpack'})
# frozenset({'traffic light', 'bicycle', 'bus', 'car', 'backpack'})
# frozenset({'traffic light', 'bicycle', 'person', 'bus', 'backpack'})
# frozenset({'truck', 'bicycle', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'handbag', 'person', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'fire hydrant', 'person', 'car'})
# frozenset({'truck', 'traffic light', 'person', 'bus', 'car'})
# frozenset({'truck', 'traffic light', 'bicycle', 'bus', 'car'})
# frozenset({'truck', 'traffic light', 'bicycle', 'person', 'car'})
# frozenset({'truck', 'traffic light', 'bicycle', 'person', 'bus'})
# frozenset({'traffic light', 'handbag', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'handbag', 'umbrella', 'person', 'car'})
# frozenset({'traffic light', 'bench', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'handbag', 'bicycle', 'person', 'car'})
# frozenset({'truck', 'traffic light', 'handbag', 'person', 'car'})
# frozenset({'truck', 'traffic light', 'motorcycle', 'person', 'car'})
# frozenset({'traffic light', 'handbag', 'bicycle', 'person', 'bus'})
# frozenset({'bench', 'sports ball', 'baseball glove', 'person', 'baseball bat'})
# frozenset({'truck', 'traffic light', 'person', 'car', 'backpack'})
# frozenset({'handbag', 'person', 'bus', 'car', 'backpack'})
# frozenset({'traffic light', 'handbag', 'bus', 'car', 'backpack'})
# frozenset({'traffic light', 'handbag', 'person', 'bus', 'backpack'})
# frozenset({'handbag', 'bicycle', 'person', 'car', 'backpack'})
# frozenset({'traffic light', 'handbag', 'bicycle', 'person', 'backpack'})
# frozenset({'traffic light', 'handbag', 'bicycle', 'car', 'backpack'})
# frozenset({'truck', 'handbag', 'person', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'handbag', 'person', 'backpack'})
# frozenset({'truck', 'traffic light', 'handbag', 'car', 'backpack'})
# frozenset({'truck', 'person', 'bus', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'bus', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'person', 'bus', 'backpack'})
# frozenset({'truck', 'traffic light', 'handbag', 'bus', 'car'})
# frozenset({'truck', 'handbag', 'person', 'bus', 'car'})
# frozenset({'truck', 'traffic light', 'handbag', 'person', 'bus'})
# frozenset({'handbag', 'bicycle', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'handbag', 'bicycle', 'bus', 'car'})
# frozenset({'traffic light', 'bench', 'handbag', 'person', 'car'})
# frozenset({'bench', 'handbag', 'umbrella', 'person', 'car'})
# frozenset({'bench', 'handbag', 'person', 'car', 'backpack'})
# frozenset({'bench', 'handbag', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'bicycle', 'person', 'bus', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'bicycle', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'handbag', 'person', 'bus', 'car', 'backpack'})
# frozenset({'traffic light', 'handbag', 'bicycle', 'person', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'handbag', 'person', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'person', 'bus', 'car', 'backpack'})
# frozenset({'truck', 'traffic light', 'handbag', 'person', 'bus', 'car'})
# frozenset({'traffic light', 'handbag', 'bicycle', 'person', 'bus', 'car'})

# %% [markdown]
# ***4. Compare Results with Mlxtend Library***
#
# To verify the results, convert the dataset into a binary matrix and use Mlxtend's apriori() and fpgrowth() functions.

# %%
# Extract all unique items
all_items = list({item for transaction in dataset for item in transaction})

# Create binary matrix
matrix = []
for transaction in dataset:
    matrix.append([1 if item in transaction else 0 for item in all_items])

df_matrix = pd.DataFrame(matrix, columns=all_items)

# %%
# Use Mlxtend Apriori
mlxtend_apriori = apriori(df_matrix, min_support=0.02, use_colnames=True)
print("\nMlxtend Apriori Results:")
print(mlxtend_apriori)
# Out:
# Mlxtend Apriori Results:
#      support                                       itemsets
# 0     0.0368                                  (sports ball)
# 1     0.1346                                 (fire hydrant)
# 2     0.0276                                          (dog)
# 3     0.0474                                     (umbrella)
# 4     0.0354                                   (cell phone)
# ..       ...                                            ...
# 139   0.0246          (bicycle, traffic light, person, car)
# 140   0.0224         (traffic light, person, car, backpack)
# 141   0.0366          (traffic light, person, car, handbag)
# 142   0.0438              (traffic light, person, car, bus)
# 143   0.0238  (baseball glove, bench, baseball bat, person)
#
# [144 rows x 2 columns]
# c:\Users\taha_kms\AppData\Local\Programs\Python\Python39\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# Use Mlxtend FP-Growth
mlxtend_fpgrowth = fpgrowth(df_matrix, min_support=0.02,)
print("\nMlxtend FP-Growth Results:")
print(mlxtend_fpgrowth)
# Out:
# c:\Users\taha_kms\AppData\Local\Programs\Python\Python39\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Mlxtend FP-Growth Results:
#      support      itemsets
# 0     0.3704          (22)
# 1     0.1332          (14)
# 2     0.0492          (72)
# 3     0.5886          (50)
# 4     0.4338          (65)
# ..       ...           ...
# 139   0.0226      (50, 75)
# 140   0.0202  (65, 50, 75)
# 141   0.0342      (41, 50)
# 142   0.0254      (65, 41)
# 143   0.0254  (65, 41, 50)
#
# [144 rows x 2 columns]

# %% [markdown]
# ***5. Compare Execution Times***

# %%
# Apriori time
apriori_time = timeit.timeit(lambda: implemented_apriori(dataset, min_support=0.02), number=1)
print(f"\nExecution time of custom Apriori: {apriori_time:.4f} seconds")
# Out:
# Execution time of custom Apriori: 8.9613 seconds

# %%
# Mlxtend Apriori time
mlxtend_apriori_time = timeit.timeit(lambda: apriori(df_matrix, min_support=0.02, use_colnames=True), number=1)
print(f"Execution time of Mlxtend Apriori: {mlxtend_apriori_time:.4f} seconds")
# Out:
# Execution time of Mlxtend Apriori: 0.0606 seconds
# c:\Users\taha_kms\AppData\Local\Programs\Python\Python39\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %%
# Mlxtend FP-Growth time
mlxtend_fpgrowth_time = timeit.timeit(lambda: fpgrowth(df_matrix, min_support=0.02, use_colnames=True), number=1)
print(f"Execution time of Mlxtend FP-Growth: {mlxtend_fpgrowth_time:.4f} seconds")
# Out:
# c:\Users\taha_kms\AppData\Local\Programs\Python\Python39\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:161: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Execution time of Mlxtend FP-Growth: 1.2898 seconds
